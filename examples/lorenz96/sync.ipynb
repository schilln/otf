# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
import jax
import numpy as np
from jax import numpy as jnp
from matplotlib import pyplot as plt

from otf import optim
from otf import time_integration as ti
from otf.system import System_ModelKnown

from plot import plot
from utils import run_update

jax.config.update("jax_platform_name", "cpu")
jax.config.update("jax_enable_x64", True)

jndarray = jnp.ndarray

# %%
def get_initial_values(I, J, J_sim):
    SEED = 42

    # Initial true state
    init = np.random.default_rng(SEED).uniform(size=I + I * J)

    u0 = jnp.array(init[:I])
    v0 = jnp.array(jnp.reshape(init[I:], (I, J)))

    # Initial simulation state
    un0 = jnp.zeros_like(u0)
    vn0 = jnp.zeros((I, J_sim))

    return (
        jnp.concatenate((jnp.expand_dims(u0, axis=1), v0), axis=1),
        jnp.concatenate((jnp.expand_dims(un0, axis=1), vn0), axis=1),
    )

# %%
# Dimensions
I, J = 40, 5
J_sim = J


def true_ode(gs: jndarray, true: jndarray) -> jndarray:
    p1, p2 = gs[6:]
    F, ds = gs[0], gs[1:6]

    u, v = true[:, 0], true[:, 1:]

    up = (
        jnp.roll(u, 1) * (jnp.roll(u, -1) - jnp.roll(u, 2))
        + p1 * jnp.sum(u * v.T, axis=0)
        - p2 * u
        + F
    )

    vp = -ds * v - jnp.expand_dims(p1 * u**2, axis=1)

    return jnp.concatenate((jnp.expand_dims(up, axis=1), vp), axis=1)


def assimilated_ode(
    cs: jndarray, assimilated: jndarray, F: float, ds: jndarray
) -> jndarray:
    p1, p2 = cs

    u, v = assimilated[:, 0], assimilated[:, 1:]

    up = (
        jnp.roll(u, 1) * (jnp.roll(u, -1) - jnp.roll(u, 2))
        + p1 * jnp.sum(u * v.T, axis=0)
        - p2 * u
        + F
    )

    vp = -ds * v - jnp.expand_dims(p1 * u**2, axis=1)

    return jnp.concatenate((jnp.expand_dims(up, axis=1), vp), axis=1)

# %%
a = jnp.arange(2 * 4).reshape(2, 4)
s_ = jnp.s_[:, :2]
mask = jnp.ones_like(a, dtype=bool)
mask = mask.at[s_].set(False)

b = jnp.dstack((a, 2 * a))

a.shape, b.shape
# Out:
# ((2, 4), (2, 4, 2))

# %%
a, b
# Out:
# (Array([[0, 1, 2, 3],
#         [4, 5, 6, 7]], dtype=int64),
#  Array([[[ 0,  0],
#          [ 1,  2],
#          [ 2,  4],
#          [ 3,  6]],
#
#         [[ 4,  8],
#          [ 5, 10],
#          [ 6, 12],
#          [ 7, 14]]], dtype=int64))

# %%
a[mask], b[mask]
# Out:
# (Array([2, 3, 6, 7], dtype=int64),
#  Array([[ 2,  4],
#         [ 3,  6],
#         [ 6, 12],
#         [ 7, 14]], dtype=int64))

# %%
a = jnp.arange(2 * 4).reshape(2, 4)
s_ = jnp.s_[:, :2]
b = jnp.dstack((a, 2 * a))

a, a.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:822, in dtype(x, canonicalize)
#     821 try:
# --> 822   dt = np.result_type(x)
#     823 except TypeError as err:
#
# TypeError: Cannot interpret 'slice(None, None, None)' as a data type
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/numpy/array.py:227, in array(object, dtype, copy, order, ndmin, device)
#     226 try:
# --> 227   dtype = dtypes._lattice_result_type(*leaves)[0] if leaves else dtypes.float_
#     228 except TypeError:
#     229   # This happens if, e.g. one of the entries is a memoryview object.
#     230   # This is rare, so we only handle it if the normal path fails.
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:832, in _lattice_result_type(*args)
#     831 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 832   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     833   if len(dtypes) == 1:
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:832, in <genexpr>(.0)
#     831 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 832   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     833   if len(dtypes) == 1:
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:601, in _dtype_and_weaktype(value)
#     600 """Return a (dtype, weak_type) tuple for the given input."""
# --> 601 return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:824, in dtype(x, canonicalize)
#     823   except TypeError as err:
# --> 824     raise TypeError(f"Cannot determine dtype of {x}") from err
#     825 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
#
# TypeError: Cannot determine dtype of slice(None, None, None)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       2 s_ = jnp.s_[:, :2]
#       3 b = jnp.dstack((a, 2*a))
# ----> 5 a, a.shape, a[(s_, s_)]
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/array.py:382, in ArrayImpl.__getitem__(self, idx)
#     377       out = lax.squeeze(out, dimensions=dims)
#     379     return ArrayImpl(
#     380         out.aval, sharding, [out], committed=False, _skip_checks=True)
# --> 382 return indexing.rewriting_take(self, idx)
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:653, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, out_sharding)
#     650 if out_sharding is not None:
#     651   return auto_axes(internal_gather, out_sharding=out_sharding
#     652                    )(arr, dynamic_idx)
# --> 653 return internal_gather(arr, dynamic_idx)
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:662, in _gather(arr, dynamic_idx, treedef, static_idx, indices_are_sorted, unique_indices, mode, fill_value)
#     659 def _gather(arr, dynamic_idx, *, treedef, static_idx, indices_are_sorted,
#     660             unique_indices, mode, fill_value):
#     661   idx = merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# --> 662   indexer = index_to_gather(np.shape(arr), idx)  # shared with _scatter_update
#     663   jnp_error._check_precondition_oob_gather(arr.shape, indexer.gather_indices)
#     664   y = arr
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:777, in index_to_gather(x_shape, idx, normalize_indices)
#     774 def index_to_gather(x_shape: Sequence[int], idx: Sequence[Any],
#     775                     normalize_indices: bool = True) -> _Indexer:
#     776   # Convert sequences to arrays
# --> 777   idx = tuple(lax_numpy.asarray(i, dtype=None if i else int)
#     778               if isinstance(i, Sequence) else i for i in idx)
#     779   abstract_idx = [_aval_or_none(i) for i in idx]
#     780   float_indices = [(i, val, aval) for i, (val, aval) in enumerate(zip(idx, abstract_idx))
#     781                    if aval is not None and dtypes.issubdtype(aval, np.inexact)]
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:777, in <genexpr>(.0)
#     774 def index_to_gather(x_shape: Sequence[int], idx: Sequence[Any],
#     775                     normalize_indices: bool = True) -> _Indexer:
#     776   # Convert sequences to arrays
# --> 777   idx = tuple(lax_numpy.asarray(i, dtype=None if i else int)
#     778               if isinstance(i, Sequence) else i for i in idx)
#     779   abstract_idx = [_aval_or_none(i) for i in idx]
#     780   float_indices = [(i, val, aval) for i, (val, aval) in enumerate(zip(idx, abstract_idx))
#     781                    if aval is not None and dtypes.issubdtype(aval, np.inexact)]
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/numpy/array.py:383, in asarray(a, dtype, order, copy, device)
#     381 if dtype is not None:
#     382   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
# --> 383 return array(a, dtype=dtype, copy=bool(copy), order=order, device=device)
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/numpy/array.py:232, in array(object, dtype, copy, order, ndmin, device)
#     228   except TypeError:
#     229     # This happens if, e.g. one of the entries is a memoryview object.
#     230     # This is rare, so we only handle it if the normal path fails.
#     231     leaves = [_convert_to_array_if_dtype_fails(leaf) for leaf in leaves]
# --> 232     dtype = dtypes._lattice_result_type(*leaves)[0]
#     234 if not weak_type:
#     235   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:832, in _lattice_result_type(*args)
#     831 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 832   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     833   if len(dtypes) == 1:
#     834     out_dtype = dtypes[0]
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:832, in <genexpr>(.0)
#     831 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 832   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     833   if len(dtypes) == 1:
#     834     out_dtype = dtypes[0]
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:601, in _dtype_and_weaktype(value)
#     599 def _dtype_and_weaktype(value: Any) -> tuple[DType, bool]:
#     600   """Return a (dtype, weak_type) tuple for the given input."""
# --> 601   return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File ~/documents/otf/.venv/lib/python3.10/site-packages/jax/_src/dtypes.py:826, in dtype(x, canonicalize)
#     824     raise TypeError(f"Cannot determine dtype of {x}") from err
#     825 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
# --> 826   raise TypeError(f"Value '{x}' with dtype {dt} is not a valid JAX array "
#     827                   "type. Only arrays of numeric types are supported by JAX.")
#     828 # TODO(jakevdp): fix return type annotation and remove this ignore.
#     829 return canonicalize_dtype(dt, allow_extended_dtype=True) if canonicalize else dt
#
# TypeError: Value 'slice(None, None, None)' with dtype object is not a valid JAX array type. Only arrays of numeric types are supported by JAX.

# %%
# System evolution parameters
import optax


g1, g2 = 1e-2, 0.5
c1, c2 = g1, g2
c1 *= 0.5
c2 *= 0.5
ds = jnp.array([0.2, 0.5, 1, 2, 5])
F = 8
mu = 50

gs = jnp.array([F, *ds, g1, g2])
cs = jnp.array([c1, c2])

observed_slice = jnp.s_[:, 0]
system = System_ModelKnown(
    mu,
    gs,
    cs,
    observed_slice,
    lambda cs, assimilated: assimilated_ode(cs, assimilated, F, ds),
    true_ode,
)
solver = ti.RK4(system)
solver = ti.ForwardEuler(system)
solver = ti.TwoStepAdamsBashforth(system, solver)
optimizer = optax.adam(1e-2)
optimizer = optim.OptaxWrapper(system, optimizer)

# Seems to work though not sure why.
# optimizer = optim.WeightedLevenbergMarquardt(system)

# Doesn't seem to work for the hyperparameters I've tried.
# optimizer = optim.LevenbergMarquardt(system)

# Simulation parameters
dt = 0.015
T0, Tf = 0, 2
t_relax = 1

cs, u_errors, v_errors, tls = run_update(
    system,
    solver,
    dt,
    T0,
    Tf,
    t_relax,
    *get_initial_values(I, J, J_sim),
    optimizer=optimizer,
)
# Out:
# [[[-5.06340980e+00 -1.14549889e+01]
#   [-1.31216772e+02  0.00000000e+00]
#   [-1.31216772e+02  0.00000000e+00]
#   [-1.31216772e+02  0.00000000e+00]
#   [-1.31216772e+02  0.00000000e+00]
#   [-1.31216772e+02  0.00000000e+00]]
#
#  [[-3.66657667e+00 -8.13623182e+00]
#   [-6.61982682e+01  0.00000000e+00]
#   [-6.61982682e+01  0.00000000e+00]
#   [-6.61982682e+01  0.00000000e+00]
#   [-6.61982682e+01  0.00000000e+00]
#   [-6.61982682e+01  0.00000000e+00]]
#
#  [[-5.24117510e-01 -1.75806244e+00]
#   [-3.09078355e+00  0.00000000e+00]
#   [-3.09078355e+00  0.00000000e+00]
#   [-3.09078355e+00  0.00000000e+00]
#   [-3.09078355e+00  0.00000000e+00]
#   [-3.09078355e+00  0.00000000e+00]]
#
#  [[-9.13659742e-01 -3.56436508e+00]
#   [-1.27046984e+01  0.00000000e+00]
#   [-1.27046984e+01  0.00000000e+00]
#   [-1.27046984e+01  0.00000000e+00]
#   [-1.27046984e+01  0.00000000e+00]
#   [-1.27046984e+01  0.00000000e+00]]
#
#  [[-1.46311202e+00 -5.59479312e+00]
#   [-3.13017101e+01  0.00000000e+00]
#   [-3.13017101e+01  0.00000000e+00]
#   [-3.13017101e+01  0.00000000e+00]
#   [-3.13017101e+01  0.00000000e+00]
#   [-3.13017101e+01  0.00000000e+00]]
#
#  [[-1.73423937e+00 -6.41938169e+00]
#   [-4.12084613e+01  0.00000000e+00]
#   [-4.12084613e+01  0.00000000e+00]
#   [-4.12084613e+01  0.00000000e+00]
#   [-4.12084613e+01  0.00000000e+00]
#   [-4.12084613e+01  0.00000000e+00]]
#
#  [[-2.05854173e+00 -7.93722022e+00]
#   [-6.29994649e+01  0.00000000e+00]
#   [-6.29994649e+01  0.00000000e+00]
#   [-6.29994649e+01  0.00000000e+00]
